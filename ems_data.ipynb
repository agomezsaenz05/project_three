# %%
import pandas as pd

# %%
file_one = "ems-incident-dispatch-data.csv"

# %%
file_one_df = pd.read_csv(file_one)
# Out:
# c:\Users\Owner\anaconda3\anaconda\envs\PythonData1\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (7,11,17,21,27,28,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# LOADING IN DATA TO CLEAN

# %%
file_one_df
# Out:
#           CAD_INCIDENT_ID        INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0               202134231  2020-07-31T23:59:51.000               UNC
# 1               202134230  2020-07-31T23:59:50.000               UNC
# 2               202134229  2020-07-31T23:59:27.000            MVAINJ
# 3               202134228  2020-07-31T23:58:54.000              SICK
# 4               202134226  2020-07-31T23:58:43.000               EDP
# ...                   ...                      ...               ...
# 20755328         50010005  2005-01-01T00:00:58.000            INJMIN
# 20755329         50010003  2005-01-01T00:00:43.000            RESPIR
# 20755330         50010004  2005-01-01T00:00:37.000             OBMIS
# 20755331         50010002  2005-01-01T00:00:25.000             OTHER
# 20755332         50010001  2005-01-01T00:00:24.000            INJURY
#
#           INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                   2             UNC
# ...

# %%
file_one_df.columns
# Out:
# Index(['CAD_INCIDENT_ID', 'INCIDENT_DATETIME', 'INITIAL_CALL_TYPE',
#        'INITIAL_SEVERITY_LEVEL_CODE', 'FINAL_CALL_TYPE',
#        'FINAL_SEVERITY_LEVEL_CODE', 'FIRST_ASSIGNMENT_DATETIME',
#        'VALID_DISPATCH_RSPNS_TIME_INDC', 'DISPATCH_RESPONSE_SECONDS_QY',
#        'FIRST_ACTIVATION_DATETIME', 'FIRST_ON_SCENE_DATETIME',
#        'VALID_INCIDENT_RSPNS_TIME_INDC', 'INCIDENT_RESPONSE_SECONDS_QY',
#        'INCIDENT_TRAVEL_TM_SECONDS_QY', 'FIRST_TO_HOSP_DATETIME',
#        'FIRST_HOSP_ARRIVAL_DATETIME', 'INCIDENT_CLOSE_DATETIME',
#        'HELD_INDICATOR', 'INCIDENT_DISPOSITION_CODE', 'BOROUGH',
#        'INCIDENT_DISPATCH_AREA', 'ZIPCODE', 'POLICEPRECINCT',
#        'CITYCOUNCILDISTRICT', 'COMMUNITYDISTRICT', 'COMMUNITYSCHOOLDISTRICT',
#        'CONGRESSIONALDISTRICT', 'REOPEN_INDICATOR', 'SPECIAL_EVENT_INDICATOR',
#        'STANDBY_INDICATOR', 'TRANSFER_INDICATOR'],
#       dtype='object')

# %% [markdown]
# CLEANING DATA FOR ANALYSYS

# %%
file_one_df_cleaned = file_one_df[['INCIDENT_DATETIME','INITIAL_SEVERITY_LEVEL_CODE','FINAL_SEVERITY_LEVEL_CODE','FIRST_ASSIGNMENT_DATETIME',
            'INCIDENT_RESPONSE_SECONDS_QY',
            'BOROUGH']]

# %%
file_one_df_cleaned['INCIDENT_DATETIME'] = pd.to_datetime(file_one_df_cleaned['INCIDENT_DATETIME'])
# Out:
# c:\Users\Owner\anaconda3\anaconda\envs\PythonData1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
file_one_df_cleaned.dtypes
# Out:
# INCIDENT_DATETIME               datetime64[ns]
# INITIAL_SEVERITY_LEVEL_CODE              int64
# FINAL_SEVERITY_LEVEL_CODE                int64
# FIRST_ASSIGNMENT_DATETIME               object
# INCIDENT_RESPONSE_SECONDS_QY           float64
# BOROUGH                                 object
# dtype: object

# %%
file_one_df_cleaned2 = file_one_df_cleaned.loc[(file_one_df_cleaned['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_cleaned['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]

# %%
file_one_df_cleaned3 = file_one_df_cleaned2.dropna(how='any')

# %%
file_one_df_cleaned4 = file_one_df_cleaned3.loc[(file_one_df_cleaned3['INITIAL_SEVERITY_LEVEL_CODE'] > 3) &(file_one_df_cleaned3['INITIAL_SEVERITY_LEVEL_CODE'] < 9)]
file_one_df_cleaned4
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357061 2020-04-21 23:59:56                            6
# 357063 2020-04-21 23:58:32                            4
# 357065 2020-04-21 23:58:24                            6
# 357066 2020-04-21 23:57:49                            7
# 357067 2020-04-21 23:57:36                            6
# ...                    ...                          ...
# 637847 2020-02-22 00:01:11                            7
# 637848 2020-02-22 00:00:53                            7
# 637849 2020-02-22 00:00:47                            4
# 637850 2020-02-22 00:00:41                            5
# 637851 2020-02-22 00:00:34                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357061                          6   2020-04-22T00:00:10.000
# 357063                          4   2020-04-21T23:58:44.000
# 357065                          6   2020-04-21T23:59:19.000
# ...

# %% [markdown]
# SEPERATING DATA BY BOROUGH FOR ANALYSIS

# %%
file_one_df_B = file_one_df_cleaned4.loc[(file_one_df_cleaned4['BOROUGH']=="BROOKLYN")]

file_one_df_B
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357063 2020-04-21 23:58:32                            4
# 357065 2020-04-21 23:58:24                            6
# 357067 2020-04-21 23:57:36                            6
# 357069 2020-04-21 23:55:24                            4
# 357084 2020-04-21 23:48:37                            6
# ...                    ...                          ...
# 637839 2020-02-22 00:03:53                            6
# 637842 2020-02-22 00:03:14                            5
# 637843 2020-02-22 00:03:13                            5
# 637844 2020-02-22 00:02:44                            6
# 637845 2020-02-22 00:02:38                            6
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357063                          4   2020-04-21T23:58:44.000
# 357065                          6   2020-04-21T23:59:19.000
# 357067                          6   2020-04-21T23:58:09.000
# ...

# %%
file_one_df_Q = file_one_df_cleaned4.loc[(file_one_df_cleaned4['BOROUGH']=="QUEENS")]

file_one_df_Q
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357076 2020-04-21 23:51:23                            4
# 357087 2020-04-21 23:47:05                            6
# 357090 2020-04-21 23:45:36                            7
# 357096 2020-04-21 23:42:59                            6
# 357101 2020-04-21 23:37:24                            7
# ...                    ...                          ...
# 637783 2020-02-22 00:28:56                            4
# 637791 2020-02-22 00:25:36                            6
# 637803 2020-02-22 00:20:04                            4
# 637834 2020-02-22 00:06:03                            4
# 637840 2020-02-22 00:03:42                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357076                          4   2020-04-21T23:51:33.000
# 357087                          6   2020-04-21T23:47:12.000
# 357090                          7   2020-04-21T23:46:15.000
# ...

# %%
file_one_df_M = file_one_df_cleaned4.loc[(file_one_df_cleaned4['BOROUGH']=="MANHATTAN")]

file_one_df_M
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357061 2020-04-21 23:59:56                            6
# 357068 2020-04-21 23:55:32                            5
# 357079 2020-04-21 23:50:58                            4
# 357080 2020-04-21 23:50:38                            6
# 357106 2020-04-21 23:35:35                            7
# ...                    ...                          ...
# 637825 2020-02-22 00:10:07                            8
# 637837 2020-02-22 00:05:06                            8
# 637848 2020-02-22 00:00:53                            7
# 637849 2020-02-22 00:00:47                            4
# 637850 2020-02-22 00:00:41                            5
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357061                          6   2020-04-22T00:00:10.000
# 357068                          5   2020-04-21T23:55:48.000
# 357079                          4   2020-04-21T23:51:12.000
# ...

# %%
file_one_df_BRONKX= file_one_df_cleaned4.loc[(file_one_df_cleaned4['BOROUGH']=="BRONX")]

file_one_df_BRONKX
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357066 2020-04-21 23:57:49                            7
# 357071 2020-04-21 23:54:25                            4
# 357072 2020-04-21 23:53:55                            4
# 357077 2020-04-21 23:51:07                            6
# 357082 2020-04-21 23:49:38                            5
# ...                    ...                          ...
# 637817 2020-02-22 00:12:17                            7
# 637827 2020-02-22 00:09:14                            5
# 637829 2020-02-22 00:08:24                            4
# 637836 2020-02-22 00:05:28                            5
# 637841 2020-02-22 00:03:21                            7
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357066                          7   2020-04-21T23:58:14.000
# 357071                          4   2020-04-21T23:54:47.000
# 357072                          4   2020-04-21T23:54:06.000
# ...

# %%
file_one_df_SI = file_one_df_cleaned4.loc[(file_one_df_cleaned4['BOROUGH']=="RICHMOND / STATEN ISLAND")]

file_one_df_SI
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357081 2020-04-21 23:49:54                            6
# 357094 2020-04-21 23:43:55                            4
# 357146 2020-04-21 23:18:21                            4
# 357178 2020-04-21 23:04:55                            5
# 357226 2020-04-21 22:45:16                            6
# ...                    ...                          ...
# 637715 2020-02-22 00:54:04                            7
# 637716 2020-02-22 00:53:34                            4
# 637835 2020-02-22 00:05:40                            6
# 637847 2020-02-22 00:01:11                            7
# 637851 2020-02-22 00:00:34                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357081                          6   2020-04-21T23:50:01.000
# 357094                          4   2020-04-21T23:44:18.000
# 357146                          4   2020-04-21T23:18:38.000
# ...

# %% [markdown]
# FINDING AVERAGE RESPONSE TIME BY BOROUGH

# %%
average_response_SI = file_one_df_SI['INCIDENT_RESPONSE_SECONDS_QY'].sum()/6252

average_response_BRONX = file_one_df_BRONKX["INCIDENT_RESPONSE_SECONDS_QY"].sum()/37463

average_response_M = file_one_df_M["INCIDENT_RESPONSE_SECONDS_QY"].sum()/38989

average_response_Q = file_one_df_Q["INCIDENT_RESPONSE_SECONDS_QY"].sum()/33183

average_response_B = file_one_df_B["INCIDENT_RESPONSE_SECONDS_QY"].sum()/44920

# %%
average_data = {'BOROUGH':['STATEN_ISLAND',"BRONX",'MANHATTAN','QUEENS',"BROOKLYN"],'AVERAGE_RESPONSE_SECONDS':[average_response_SI.round(),average_response_BRONX.round(),
                                                                                                                average_response_M.round(),average_response_Q.round(),
                                                                                                                average_response_B.round()]}

# %%
average_per_borough_df = pd.DataFrame(average_data)

average_per_borough_df
# Out:
#          BOROUGH  AVERAGE_RESPONSE_SECONDS
# 0  STATEN_ISLAND                     524.0
# 1          BRONX                    1636.0
# 2      MANHATTAN                     821.0
# 3         QUEENS                     993.0
# 4       BROOKLYN                    1036.0

# %% [markdown]
# BEFORE AND AFTER COVID FOR NYC

# %%
before_covid_df = file_one_df_cleaned.loc[(file_one_df_cleaned['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_cleaned['INCIDENT_DATETIME'] < "2020-03-22T00:00:00.000")]

before_covid_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 512893 2020-03-21 23:59:47                            7
# 512894 2020-03-21 23:58:43                            2
# 512895 2020-03-21 23:58:41                            2
# 512896 2020-03-21 23:58:38                            4
# 512897 2020-03-21 23:58:33                            2
# ...                    ...                          ...
# 637847 2020-02-22 00:01:11                            7
# 637848 2020-02-22 00:00:53                            7
# 637849 2020-02-22 00:00:47                            4
# 637850 2020-02-22 00:00:41                            5
# 637851 2020-02-22 00:00:34                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 512893                          7   2020-03-22T00:00:31.000
# 512894                          6   2020-03-22T00:00:09.000
# 512895                          2   2020-03-21T23:59:49.000
# ...

# %%
after_covid_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INCIDENT_DATETIME'] > "2020-03-22T00:00:00.000") & (file_one_df_cleaned['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]
after_covid_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357061 2020-04-21 23:59:56                            6
# 357062 2020-04-21 23:59:26                            2
# 357063 2020-04-21 23:58:32                            4
# 357064 2020-04-21 23:58:28                            2
# 357065 2020-04-21 23:58:24                            6
# ...                    ...                          ...
# 512888 2020-03-22 00:02:03                            4
# 512889 2020-03-22 00:01:04                            2
# 512890 2020-03-22 00:00:46                            3
# 512891 2020-03-22 00:00:18                            4
# 512892 2020-03-22 00:00:08                            6
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357061                          6   2020-04-22T00:00:10.000
# 357062                          2   2020-04-21T23:59:56.000
# 357063                          4   2020-04-21T23:58:44.000
# ...

# %%
average_response_before_covid = before_covid_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/124959

average_response_after_covid = after_covid_df["INCIDENT_RESPONSE_SECONDS_QY"].sum()/155832

# %%
average_data_covid = {'LOCKDOWN':['NO',"YES"],'AVERAGE_RESPONSE_SECONDS':[average_response_before_covid.round(),average_response_after_covid.round()]}

# %%
average_before_after_covid_df = pd.DataFrame(average_data_covid)

average_before_after_covid_df
# Out:
#   LOCKDOWN  AVERAGE_RESPONSE_SECONDS
# 0       NO                     602.0
# 1      YES                     954.0

# %% [markdown]
# BEFORE AND AFTER COVID BY BOROUGH

# %%
#Staten Island

before_covid_SI_df = file_one_df_SI.loc[(file_one_df_SI['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_SI['INCIDENT_DATETIME'] < "2020-03-22T00:00:00.000")]

before_covid_SI_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 512961 2020-03-21 23:40:18                            4
# 512982 2020-03-21 23:34:23                            4
# 513009 2020-03-21 23:22:50                            5
# 513017 2020-03-21 23:20:34                            6
# 513045 2020-03-21 23:13:07                            7
# ...                    ...                          ...
# 637715 2020-02-22 00:54:04                            7
# 637716 2020-02-22 00:53:34                            4
# 637835 2020-02-22 00:05:40                            6
# 637847 2020-02-22 00:01:11                            7
# 637851 2020-02-22 00:00:34                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 512961                          4   2020-03-21T23:41:06.000
# 512982                          4   2020-03-21T23:34:32.000
# 513009                          5   2020-03-21T23:23:00.000
# ...

# %%
after_covid_SI_df =  file_one_df_SI.loc[(file_one_df_SI['INCIDENT_DATETIME'] > "2020-03-22T00:00:00.000") & (file_one_df_SI['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]
after_covid_SI_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357081 2020-04-21 23:49:54                            6
# 357094 2020-04-21 23:43:55                            4
# 357146 2020-04-21 23:18:21                            4
# 357178 2020-04-21 23:04:55                            5
# 357226 2020-04-21 22:45:16                            6
# ...                    ...                          ...
# 512666 2020-03-22 01:19:02                            4
# 512746 2020-03-22 00:47:22                            7
# 512792 2020-03-22 00:28:45                            6
# 512834 2020-03-22 00:15:27                            4
# 512864 2020-03-22 00:08:12                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357081                          6   2020-04-21T23:50:01.000
# 357094                          4   2020-04-21T23:44:18.000
# 357146                          4   2020-04-21T23:18:38.000
# ...

# %%
#Manhattan
before_covid_M_df = file_one_df_M.loc[(file_one_df_M['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_M['INCIDENT_DATETIME'] < "2020-03-22T00:00:00.000")]

before_covid_M_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 512893 2020-03-21 23:59:47                            7
# 512900 2020-03-21 23:57:32                            4
# 512901 2020-03-21 23:57:24                            4
# 512905 2020-03-21 23:56:11                            5
# 512917 2020-03-21 23:52:39                            7
# ...                    ...                          ...
# 637825 2020-02-22 00:10:07                            8
# 637837 2020-02-22 00:05:06                            8
# 637848 2020-02-22 00:00:53                            7
# 637849 2020-02-22 00:00:47                            4
# 637850 2020-02-22 00:00:41                            5
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 512893                          7   2020-03-22T00:00:31.000
# 512900                          4   2020-03-21T23:57:42.000
# 512901                          4   2020-03-21T23:57:43.000
# ...

# %%
after_covid_M_df =  file_one_df_M.loc[(file_one_df_M['INCIDENT_DATETIME'] > "2020-03-22T00:00:00.000") & (file_one_df_M['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]
after_covid_M_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357061 2020-04-21 23:59:56                            6
# 357068 2020-04-21 23:55:32                            5
# 357079 2020-04-21 23:50:58                            4
# 357080 2020-04-21 23:50:38                            6
# 357106 2020-04-21 23:35:35                            7
# ...                    ...                          ...
# 512852 2020-03-22 00:10:17                            5
# 512863 2020-03-22 00:08:14                            6
# 512878 2020-03-22 00:04:47                            6
# 512879 2020-03-22 00:04:26                            6
# 512892 2020-03-22 00:00:08                            6
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357061                          6   2020-04-22T00:00:10.000
# 357068                          5   2020-04-21T23:55:48.000
# 357079                          4   2020-04-21T23:51:12.000
# ...

# %%
#Queens
before_covid_Q_df = file_one_df_Q.loc[(file_one_df_Q['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_Q['INCIDENT_DATETIME'] < "2020-03-22T00:00:00.000")]

before_covid_Q_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 512909 2020-03-21 23:54:28                            6
# 512910 2020-03-21 23:54:27                            6
# 512921 2020-03-21 23:51:39                            5
# 512931 2020-03-21 23:48:16                            5
# 512942 2020-03-21 23:45:05                            4
# ...                    ...                          ...
# 637783 2020-02-22 00:28:56                            4
# 637791 2020-02-22 00:25:36                            6
# 637803 2020-02-22 00:20:04                            4
# 637834 2020-02-22 00:06:03                            4
# 637840 2020-02-22 00:03:42                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 512909                          6   2020-03-22T00:08:40.000
# 512910                          6   2020-03-22T00:30:50.000
# 512921                          5   2020-03-21T23:52:02.000
# ...

# %%
after_covid_Q_df =  file_one_df_Q.loc[(file_one_df_Q['INCIDENT_DATETIME'] > "2020-03-22T00:00:00.000") & (file_one_df_Q['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]

after_covid_Q_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357076 2020-04-21 23:51:23                            4
# 357087 2020-04-21 23:47:05                            6
# 357090 2020-04-21 23:45:36                            7
# 357096 2020-04-21 23:42:59                            6
# 357101 2020-04-21 23:37:24                            7
# ...                    ...                          ...
# 512870 2020-03-22 00:06:54                            6
# 512873 2020-03-22 00:06:08                            6
# 512875 2020-03-22 00:05:49                            6
# 512876 2020-03-22 00:05:35                            5
# 512888 2020-03-22 00:02:03                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357076                          4   2020-04-21T23:51:33.000
# 357087                          6   2020-04-21T23:47:12.000
# 357090                          7   2020-04-21T23:46:15.000
# ...

# %%
#Brooklyn
before_covid_Br_df = file_one_df_B.loc[(file_one_df_B['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_B['INCIDENT_DATETIME'] < "2020-03-22T00:00:00.000")]

before_covid_Br_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 512896 2020-03-21 23:58:38                            4
# 512906 2020-03-21 23:56:10                            5
# 512907 2020-03-21 23:55:19                            5
# 512908 2020-03-21 23:55:10                            6
# 512912 2020-03-21 23:54:20                            5
# ...                    ...                          ...
# 637839 2020-02-22 00:03:53                            6
# 637842 2020-02-22 00:03:14                            5
# 637843 2020-02-22 00:03:13                            5
# 637844 2020-02-22 00:02:44                            6
# 637845 2020-02-22 00:02:38                            6
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 512896                          4   2020-03-22T00:10:15.000
# 512906                          5   2020-03-21T23:56:40.000
# 512907                          5   2020-03-22T00:26:16.000
# ...

# %%
after_covid_Br_df =  file_one_df_B.loc[(file_one_df_B['INCIDENT_DATETIME'] > "2020-03-22T00:00:00.000") & (file_one_df_B['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]

after_covid_Br_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357063 2020-04-21 23:58:32                            4
# 357065 2020-04-21 23:58:24                            6
# 357067 2020-04-21 23:57:36                            6
# 357069 2020-04-21 23:55:24                            4
# 357084 2020-04-21 23:48:37                            6
# ...                    ...                          ...
# 512847 2020-03-22 00:11:47                            4
# 512869 2020-03-22 00:07:12                            4
# 512880 2020-03-22 00:03:55                            4
# 512881 2020-03-22 00:03:47                            6
# 512891 2020-03-22 00:00:18                            4
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357063                          4   2020-04-21T23:58:44.000
# 357065                          6   2020-04-21T23:59:19.000
# 357067                          6   2020-04-21T23:58:09.000
# ...

# %%
#Bronx
before_covid_Bx_df = file_one_df_BRONKX.loc[(file_one_df_BRONKX['INCIDENT_DATETIME'] > "2020-02-22T00:00:00.000") & (file_one_df_BRONKX['INCIDENT_DATETIME'] < "2020-03-22T00:00:00.000")]

before_covid_Bx_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 512911 2020-03-21 23:54:24                            4
# 512913 2020-03-21 23:53:56                            6
# 512916 2020-03-21 23:53:07                            4
# 512920 2020-03-21 23:51:48                            5
# 512929 2020-03-21 23:49:24                            4
# ...                    ...                          ...
# 637817 2020-02-22 00:12:17                            7
# 637827 2020-02-22 00:09:14                            5
# 637829 2020-02-22 00:08:24                            4
# 637836 2020-02-22 00:05:28                            5
# 637841 2020-02-22 00:03:21                            7
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 512911                          4   2020-03-22T00:06:16.000
# 512913                          2   2020-03-22T00:06:09.000
# 512916                          4   2020-03-22T00:05:54.000
# ...

# %%
after_covid_Bx_df =  file_one_df_BRONKX.loc[(file_one_df_BRONKX['INCIDENT_DATETIME'] > "2020-03-22T00:00:00.000") & (file_one_df_BRONKX['INCIDENT_DATETIME'] < "2020-04-22T00:00:00.000")]

after_covid_Bx_df
# Out:
#          INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 357066 2020-04-21 23:57:49                            7
# 357071 2020-04-21 23:54:25                            4
# 357072 2020-04-21 23:53:55                            4
# 357077 2020-04-21 23:51:07                            6
# 357082 2020-04-21 23:49:38                            5
# ...                    ...                          ...
# 512866 2020-03-22 00:07:44                            6
# 512868 2020-03-22 00:07:32                            4
# 512871 2020-03-22 00:06:22                            4
# 512883 2020-03-22 00:03:19                            4
# 512884 2020-03-22 00:03:07                            6
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 357066                          7   2020-04-21T23:58:14.000
# 357071                          4   2020-04-21T23:54:47.000
# 357072                          4   2020-04-21T23:54:06.000
# ...

# %%
average_response_before_covid_SI = before_covid_SI_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/3025

average_response_after_covid_SI = after_covid_SI_df["INCIDENT_RESPONSE_SECONDS_QY"].sum()/3227

average_response_before_covid_M = before_covid_M_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/20390

average_response_after_covid_M = after_covid_M_df["INCIDENT_RESPONSE_SECONDS_QY"].sum()/18599

average_response_before_covid_Q = before_covid_Q_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/15954

average_response_after_covid_Q = after_covid_Q_df["INCIDENT_RESPONSE_SECONDS_QY"].sum()/17230

average_response_before_covid_Br = before_covid_Br_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/22302

average_response_after_covid_Br = after_covid_Br_df["INCIDENT_RESPONSE_SECONDS_QY"].sum()/22618

average_response_before_covid_Bx = before_covid_Bx_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/18987

average_response_after_covid_Bx = after_covid_Bx_df["INCIDENT_RESPONSE_SECONDS_QY"].sum()/18477

# %%
average_data_before_covid = {'BOROUGH':['STATEN_ISLAND',"BRONX",'MANHATTAN','QUEENS',"BROOKLYN"],'AVERAGE_RESPONSE_SECONDS_BEFORE_COVID':[average_response_before_covid_SI.round(),
                                                                                                                             average_response_before_covid_Bx.round(),
                                                                                                                             average_response_before_covid_M.round(),
                                                                                                                             average_response_before_covid_Q.round(),
                                                                                                                             average_response_before_covid_Br.round()]}

average_data_after_covid = {'BOROUGH':['STATEN_ISLAND',"BRONX",'MANHATTAN','QUEENS',"BROOKLYN"],'AVERAGE_RESPONSE_SECONDS_AFTER_COVID':[average_response_after_covid_SI.round(),
                                                                                                                             average_response_after_covid_Bx.round(),
                                                                                                                             average_response_after_covid_M.round(),
                                                                                                                             average_response_after_covid_Q.round(),
                                                                                                                             average_response_after_covid_Br.round()]}

# %%
average_before_covid_df = pd.DataFrame(average_data_before_covid)

average_before_covid_df
# Out:
#          BOROUGH  AVERAGE_RESPONSE_SECONDS_BEFORE_COVID
# 0  STATEN_ISLAND                                  517.0
# 1          BRONX                                  869.0
# 2      MANHATTAN                                  819.0
# 3         QUEENS                                  610.0
# 4       BROOKLYN                                  631.0

# %%
average_after_covid_df = pd.DataFrame(average_data_after_covid)

average_after_covid_df
# Out:
#          BOROUGH  AVERAGE_RESPONSE_SECONDS_AFTER_COVID
# 0  STATEN_ISLAND                                 530.0
# 1          BRONX                                2425.0
# 2      MANHATTAN                                 823.0
# 3         QUEENS                                1348.0
# 4       BROOKLYN                                1436.0

# %% [markdown]
# INITIAL SEVERITY VS RESPONSE TIME NYC

# %%
initial_severity4_vs_response_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==4 )]

initial_severity4_vs_response_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 2        2020-07-31 23:59:27                            4
# 6        2020-07-31 23:57:57                            4
# 12       2020-07-31 23:54:21                            4
# 26       2020-07-31 23:46:47                            4
# 29       2020-07-31 23:45:48                            4
# ...                      ...                          ...
# 20755313 2005-01-01 00:05:06                            4
# 20755319 2005-01-01 00:02:27                            4
# 20755327 2005-01-01 00:01:03                            4
# 20755329 2005-01-01 00:00:43                            4
# 20755330 2005-01-01 00:00:37                            4
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 2                                 4   2020-07-31T23:59:38.000
# 6                                 3   2020-07-31T23:58:06.000
# 12                                4   2020-07-31T23:56:26.000
# ...

# %%
initial_severity5_vs_response_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==5 )]

initial_severity5_vs_response_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 9        2020-07-31 23:56:24                            5
# 19       2020-07-31 23:51:01                            5
# 28       2020-07-31 23:45:49                            5
# 32       2020-07-31 23:45:20                            5
# 36       2020-07-31 23:44:57                            5
# ...                      ...                          ...
# 20755310 2005-01-01 00:06:37                            5
# 20755311 2005-01-01 00:06:29                            5
# 20755314 2005-01-01 00:04:57                            5
# 20755318 2005-01-01 00:02:28                            5
# 20755332 2005-01-01 00:00:24                            5
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 9                                 5   2020-07-31T23:56:54.000
# 19                                5   2020-07-31T23:51:12.000
# 28                                5   2020-07-31T23:46:06.000
# ...

# %%
initial_severity6_vs_response_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==6 )]

initial_severity6_vs_response_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 3        2020-07-31 23:58:54                            6
# 7        2020-07-31 23:57:51                            6
# 8        2020-07-31 23:56:52                            6
# 14       2020-07-31 23:53:59                            6
# 17       2020-07-31 23:52:03                            6
# ...                      ...                          ...
# 20755299 2005-01-01 00:09:29                            6
# 20755309 2005-01-01 00:06:42                            6
# 20755322 2005-01-01 00:01:29                            6
# 20755324 2005-01-01 00:01:19                            6
# 20755331 2005-01-01 00:00:25                            6
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 3                                 6   2020-08-01T00:00:30.000
# 7                                 6   2020-08-01T00:27:05.000
# 8                                 6   2020-07-31T23:59:17.000
# ...

# %%
initial_severity7_vs_response_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==7 )]

initial_severity7_vs_response_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 4        2020-07-31 23:58:43                            7
# 5        2020-07-31 23:58:02                            7
# 10       2020-07-31 23:54:53                            7
# 16       2020-07-31 23:52:29                            7
# 20       2020-07-31 23:50:28                            7
# ...                      ...                          ...
# 20755253 2005-01-01 00:20:11                            7
# 20755287 2005-01-01 00:12:48                            7
# 20755294 2005-01-01 00:10:38                            7
# 20755317 2005-01-01 00:02:31                            7
# 20755328 2005-01-01 00:00:58                            7
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 4                                 7   2020-07-31T23:59:17.000
# 5                                 7   2020-07-31T23:58:40.000
# 10                                7   2020-07-31T23:57:02.000
# ...

# %%
initial_severity8_vs_response_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==8 )]

initial_severity8_vs_response_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 277      2020-07-31 22:19:43                            8
# 399      2020-07-31 21:42:25                            8
# 919      2020-07-31 19:06:09                            8
# 1411     2020-07-31 16:35:46                            8
# 1964     2020-07-31 13:49:41                            8
# ...                      ...                          ...
# 20753216 2005-01-01 09:49:40                            8
# 20753281 2005-01-01 09:29:40                            8
# 20754695 2005-01-01 02:18:44                            8
# 20755198 2005-01-01 00:35:54                            8
# 20755208 2005-01-01 00:32:48                            8
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 277                               8   2020-07-31T22:20:16.000
# 399                               8   2020-07-31T21:43:55.000
# 919                               8   2020-07-31T19:07:58.000
# ...

# %%
initial_severity9_vs_response_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==9 )]

initial_severity9_vs_response_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 182147   2020-06-12 19:39:18                            9
# 388880   2020-04-13 14:29:51                            9
# 455011   2020-03-31 22:47:41                            9
# 797668   2020-01-14 20:31:48                            9
# 841638   2020-01-04 16:02:37                            9
# ...                      ...                          ...
# 20194498 2005-06-30 04:08:23                            9
# 20325708 2005-05-21 01:08:43                            9
# 20377960 2005-05-04 15:26:20                            9
# 20654464 2005-02-02 16:32:37                            9
# 20678304 2005-01-25 18:17:25                            9
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 182147                            5   2020-06-12T19:39:18.000
# 388880                            6   2020-04-13T14:31:55.000
# 455011                            5   2020-03-31T22:47:41.000
# ...

# %%
initial_severity4_vs_response_avg = initial_severity4_vs_response_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/4315961
initial_severity5_vs_response_avg = initial_severity5_vs_response_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/3815768
initial_severity6_vs_response_avg = initial_severity6_vs_response_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/3528142
initial_severity7_vs_response_avg = initial_severity7_vs_response_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/1908213
initial_severity8_vs_response_avg = initial_severity8_vs_response_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/78214

# %%
average_data_by_initial_s = {'SEVERITY_LEVEL':['4',"5",'6','7',"8"],'AVERAGE_RESPONSE_SECONDS':[initial_severity4_vs_response_avg.round(),
                                                                                                                             initial_severity5_vs_response_avg.round(),
                                                                                                                             initial_severity6_vs_response_avg.round(),
                                                                                                                             initial_severity7_vs_response_avg.round(),
                                                                                                                             initial_severity8_vs_response_avg.round()
                                                                                                                             ]}

# %%
initial_severity_vs_response_df = pd.DataFrame(average_data_by_initial_s)

initial_severity_vs_response_df
# Out:
#   SEVERITY_LEVEL  AVERAGE_RESPONSE_SECONDS
# 0              4                     519.0
# 1              5                     557.0
# 2              6                     599.0
# 3              7                     778.0
# 4              8                    1959.0

# %% [markdown]
# INITIAL SEVERITY VS RESPONSE TIME BY BOROUGH

# %%
#STATEN ISLAND
initial_severity4_SI_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==4) &(file_one_df_cleaned['BOROUGH'] =="RICHMOND / STATEN ISLAND" )]

initial_severity4_SI_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 37       2020-07-31 23:44:10                            4
# 210      2020-07-31 22:41:21                            4
# 284      2020-07-31 22:18:34                            4
# 415      2020-07-31 21:36:55                            4
# 579      2020-07-31 20:47:17                            4
# ...                      ...                          ...
# 20753962 2005-01-01 04:50:39                            4
# 20753999 2005-01-01 04:40:51                            4
# 20754016 2005-01-01 04:36:34                            4
# 20754323 2005-01-01 03:30:22                            4
# 20755105 2005-01-01 00:54:45                            4
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 37                                4   2020-07-31T23:44:18.000
# 210                               4   2020-07-31T22:41:35.000
# 284                               4   2020-07-31T22:18:40.000
# ...

# %%
initial_severity5_SI_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==5) &(file_one_df_cleaned['BOROUGH'] =="RICHMOND / STATEN ISLAND" )]

initial_severity5_SI_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 36       2020-07-31 23:44:57                            5
# 43       2020-07-31 23:41:44                            5
# 313      2020-07-31 22:06:10                            5
# 672      2020-07-31 20:21:38                            5
# 753      2020-07-31 19:58:57                            5
# ...                      ...                          ...
# 20754907 2005-01-01 01:32:55                            5
# 20755015 2005-01-01 01:12:53                            5
# 20755139 2005-01-01 00:48:37                            5
# 20755254 2005-01-01 00:19:42                            5
# 20755286 2005-01-01 00:12:57                            5
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 36                                5   2020-07-31T23:45:16.000
# 43                                5   2020-07-31T23:41:52.000
# 313                               5   2020-07-31T22:06:18.000
# ...

# %%
initial_severity6_SI_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==6) &(file_one_df_cleaned['BOROUGH'] =="RICHMOND / STATEN ISLAND" )]

initial_severity6_SI_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 355      2020-07-31 21:52:55                            6
# 591      2020-07-31 20:43:49                            6
# 619      2020-07-31 20:35:49                            6
# 1115     2020-07-31 18:02:18                            6
# 1263     2020-07-31 17:15:57                            6
# ...                      ...                          ...
# 20753844 2005-01-01 05:26:29                            6
# 20753914 2005-01-01 05:06:30                            6
# 20753963 2005-01-01 04:50:26                            6
# 20754762 2005-01-01 02:05:54                            6
# 20755262 2005-01-01 00:19:03                            6
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 355                               6   2020-07-31T21:53:01.000
# 591                               2   2020-07-31T20:46:03.000
# 619                               2   2020-07-31T20:37:14.000
# ...

# %%
initial_severity7_SI_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==7) &(file_one_df_cleaned['BOROUGH'] =="RICHMOND / STATEN ISLAND" )]

initial_severity7_SI_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 307      2020-07-31 22:08:56                            7
# 358      2020-07-31 21:52:17                            7
# 825      2020-07-31 19:38:51                            7
# 1073     2020-07-31 18:14:15                            7
# 1165     2020-07-31 17:46:04                            7
# ...                      ...                          ...
# 20753455 2005-01-01 08:12:09                            7
# 20753657 2005-01-01 06:36:48                            7
# 20754057 2005-01-01 04:25:03                            7
# 20754862 2005-01-01 01:44:02                            7
# 20755204 2005-01-01 00:33:50                            7
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 307                               7   2020-07-31T22:09:03.000
# 358                               7   2020-07-31T21:52:26.000
# 825                               7   2020-07-31T19:39:50.000
# ...

# %%
initial_severity8_SI_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==8) &(file_one_df_cleaned['BOROUGH'] =="RICHMOND / STATEN ISLAND" )]

initial_severity8_SI_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 19366    2020-07-26 21:12:19                            8
# 19577    2020-07-26 20:10:20                            8
# 32800    2020-07-23 09:02:39                            8
# 42055    2020-07-20 19:17:10                            8
# 50518    2020-07-18 16:13:39                            8
# ...                      ...                          ...
# 20737332 2005-01-05 23:50:40                            8
# 20741980 2005-01-04 15:16:46                            8
# 20744014 2005-01-04 00:10:58                            8
# 20746750 2005-01-03 09:30:31                            8
# 20750390 2005-01-02 04:47:28                            8
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 19366                             8   2020-07-26T21:12:27.000
# 19577                             8   2020-07-26T20:10:20.000
# 32800                             8   2020-07-23T09:02:50.000
# ...

# %%
initial_severity4_SI_avg = initial_severity4_SI_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/190651
initial_severity5_SI_avg = initial_severity5_SI_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/141148
initial_severity6_SI_avg = initial_severity6_SI_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/128185
initial_severity7_SI_avg = initial_severity7_SI_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/78495
initial_severity8_SI_avg = initial_severity8_SI_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/4063

# %%
average_initial_SI = {'SEVERITY_LEVEL':['4',"5",'6','7',"8"],'AVERAGE_RESPONSE_SECONDS':[initial_severity4_SI_avg.round(),
                                                                                                                             initial_severity5_SI_avg.round(),
                                                                                                                             initial_severity6_SI_avg.round(),
                                                                                                                             initial_severity7_SI_avg.round(),
                                                                                                                             initial_severity8_SI_avg.round()
                                                                                                                             ]}

# %%
initial_severity_SI_df = pd.DataFrame(average_initial_SI)

initial_severity_SI_df
# Out:
#   SEVERITY_LEVEL  AVERAGE_RESPONSE_SECONDS
# 0              4                     432.0
# 1              5                     450.0
# 2              6                     450.0
# 3              7                     576.0
# 4              8                    1489.0

# %%
#MANHATTAN
initial_severity4_M_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==4) &(file_one_df_cleaned['BOROUGH'] =="MANHATTAN" )]

initial_severity4_M_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 2        2020-07-31 23:59:27                            4
# 33       2020-07-31 23:45:15                            4
# 34       2020-07-31 23:45:11                            4
# 74       2020-07-31 23:27:57                            4
# 81       2020-07-31 23:25:11                            4
# ...                      ...                          ...
# 20755233 2005-01-01 00:26:56                            4
# 20755270 2005-01-01 00:16:57                            4
# 20755307 2005-01-01 00:07:27                            4
# 20755313 2005-01-01 00:05:06                            4
# 20755330 2005-01-01 00:00:37                            4
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 2                                 4   2020-07-31T23:59:38.000
# 33                                4   2020-07-31T23:45:55.000
# 34                                4   2020-07-31T23:45:20.000
# ...

# %%
initial_severity5_M_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==5) &(file_one_df_cleaned['BOROUGH'] =="MANHATTAN" )]

initial_severity5_M_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 19       2020-07-31 23:51:01                            5
# 28       2020-07-31 23:45:49                            5
# 39       2020-07-31 23:43:50                            5
# 50       2020-07-31 23:38:04                            5
# 51       2020-07-31 23:37:22                            5
# ...                      ...                          ...
# 20755248 2005-01-01 00:21:20                            5
# 20755257 2005-01-01 00:19:32                            5
# 20755261 2005-01-01 00:19:12                            5
# 20755289 2005-01-01 00:12:03                            5
# 20755302 2005-01-01 00:08:52                            5
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 19                                5   2020-07-31T23:51:12.000
# 28                                5   2020-07-31T23:46:06.000
# 39                                5   2020-07-31T23:43:57.000
# ...

# %%
initial_severity6_M_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==6) &(file_one_df_cleaned['BOROUGH'] =="MANHATTAN" )]

initial_severity6_M_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 8        2020-07-31 23:56:52                            6
# 14       2020-07-31 23:53:59                            6
# 17       2020-07-31 23:52:03                            6
# 83       2020-07-31 23:25:01                            6
# 166      2020-07-31 22:57:53                            6
# ...                      ...                          ...
# 20755209 2005-01-01 00:32:32                            6
# 20755220 2005-01-01 00:28:55                            6
# 20755259 2005-01-01 00:19:26                            6
# 20755268 2005-01-01 00:17:11                            6
# 20755324 2005-01-01 00:01:19                            6
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 8                                 6   2020-07-31T23:59:17.000
# 14                                6   2020-07-31T23:53:59.000
# 17                                6   2020-07-31T23:52:46.000
# ...

# %%
initial_severity7_M_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==7) &(file_one_df_cleaned['BOROUGH'] =="MANHATTAN" )]

initial_severity7_M_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 45       2020-07-31 23:39:56                            7
# 72       2020-07-31 23:28:35                            7
# 87       2020-07-31 23:23:38                            7
# 134      2020-07-31 23:07:17                            7
# 139      2020-07-31 23:05:59                            7
# ...                      ...                          ...
# 20755032 2005-01-01 01:10:10                            7
# 20755108 2005-01-01 00:53:53                            7
# 20755144 2005-01-01 00:47:57                            7
# 20755294 2005-01-01 00:10:38                            7
# 20755317 2005-01-01 00:02:31                            7
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 45                                7   2020-07-31T23:40:42.000
# 72                                7   2020-07-31T23:28:47.000
# 87                                7   2020-07-31T23:23:49.000
# ...

# %%
initial_severity8_M_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==8) &(file_one_df_cleaned['BOROUGH'] =="MANHATTAN" )]

initial_severity8_M_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 277      2020-07-31 22:19:43                            8
# 399      2020-07-31 21:42:25                            8
# 7232     2020-07-30 00:48:33                            8
# 10189    2020-07-29 09:04:24                            8
# 10261    2020-07-29 08:35:44                            8
# ...                      ...                          ...
# 20751531 2005-01-01 19:48:24                            8
# 20751934 2005-01-01 17:28:22                            8
# 20752045 2005-01-01 16:50:22                            8
# 20754695 2005-01-01 02:18:44                            8
# 20755208 2005-01-01 00:32:48                            8
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 277                               8   2020-07-31T22:20:16.000
# 399                               8   2020-07-31T21:43:55.000
# 7232                              7   2020-07-30T00:49:06.000
# ...

# %%
initial_severity4_M_avg = initial_severity4_M_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/1091177
initial_severity5_M_avg = initial_severity5_M_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/914845
initial_severity6_M_avg = initial_severity6_M_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/871340
initial_severity7_M_avg = initial_severity7_M_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/494591
initial_severity8_M_avg = initial_severity8_M_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/20761

# %%
average_initial_M = {'SEVERITY_LEVEL':['4',"5",'6','7',"8"],'AVERAGE_RESPONSE_SECONDS':[initial_severity4_M_avg.round(),
                                                                                                                             initial_severity5_M_avg.round(),
                                                                                                                             initial_severity6_M_avg.round(),
                                                                                                                             initial_severity7_M_avg.round(),
                                                                                                                             initial_severity8_M_avg.round()
                                                                                                                             ]}

# %%
initial_severity_M_df = pd.DataFrame(average_initial_M)

initial_severity_M_df
# Out:
#   SEVERITY_LEVEL  AVERAGE_RESPONSE_SECONDS
# 0              4                     546.0
# 1              5                     594.0
# 2              6                     638.0
# 3              7                     857.0
# 4              8                    2432.0

# %%
#Queens
initial_severity4_Q_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==4) &(file_one_df_cleaned['BOROUGH'] =="QUEENS" )]

initial_severity4_Q_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 6        2020-07-31 23:57:57                            4
# 29       2020-07-31 23:45:48                            4
# 44       2020-07-31 23:40:30                            4
# 56       2020-07-31 23:35:40                            4
# 71       2020-07-31 23:29:25                            4
# ...                      ...                          ...
# 20755217 2005-01-01 00:30:07                            4
# 20755243 2005-01-01 00:22:58                            4
# 20755251 2005-01-01 00:20:26                            4
# 20755300 2005-01-01 00:09:20                            4
# 20755327 2005-01-01 00:01:03                            4
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 6                                 3   2020-07-31T23:58:06.000
# 29                                4   2020-07-31T23:45:54.000
# 44                                4   2020-07-31T23:41:19.000
# ...

# %%
initial_severity5_Q_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==5) &(file_one_df_cleaned['BOROUGH'] =="QUEENS" )]

initial_severity5_Q_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 40       2020-07-31 23:43:44                            5
# 53       2020-07-31 23:36:44                            5
# 70       2020-07-31 23:29:31                            5
# 102      2020-07-31 23:17:00                            5
# 163      2020-07-31 22:58:20                            5
# ...                      ...                          ...
# 20755078 2005-01-01 01:00:31                            5
# 20755104 2005-01-01 00:55:18                            5
# 20755124 2005-01-01 00:51:49                            5
# 20755138 2005-01-01 00:48:57                            5
# 20755193 2005-01-01 00:36:43                            5
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 40                                5   2020-07-31T23:44:11.000
# 53                                5   2020-07-31T23:37:15.000
# 70                                5   2020-07-31T23:30:06.000
# ...

# %%
initial_severity6_Q_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==6) &(file_one_df_cleaned['BOROUGH'] =="QUEENS" )]

initial_severity6_Q_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 7        2020-07-31 23:57:51                            6
# 27       2020-07-31 23:46:39                            6
# 58       2020-07-31 23:34:26                            6
# 86       2020-07-31 23:23:57                            6
# 131      2020-07-31 23:08:33                            6
# ...                      ...                          ...
# 20755053 2005-01-01 01:06:50                            6
# 20755072 2005-01-01 01:02:01                            6
# 20755118 2005-01-01 00:52:38                            6
# 20755161 2005-01-01 00:42:47                            6
# 20755279 2005-01-01 00:15:00                            6
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 7                                 6   2020-08-01T00:27:05.000
# 27                                6   2020-07-31T23:58:20.000
# 58                                6   2020-07-31T23:36:05.000
# ...

# %%
initial_severity7_Q_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==7) &(file_one_df_cleaned['BOROUGH'] =="QUEENS" )]

initial_severity7_Q_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 4        2020-07-31 23:58:43                            7
# 16       2020-07-31 23:52:29                            7
# 22       2020-07-31 23:49:07                            7
# 75       2020-07-31 23:27:38                            7
# 117      2020-07-31 23:12:03                            7
# ...                      ...                          ...
# 20754879 2005-01-01 01:40:35                            7
# 20755113 2005-01-01 00:53:08                            7
# 20755175 2005-01-01 00:40:12                            7
# 20755230 2005-01-01 00:27:23                            7
# 20755253 2005-01-01 00:20:11                            7
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 4                                 7   2020-07-31T23:59:17.000
# 16                                7   2020-07-31T23:53:06.000
# 22                                7   2020-07-31T23:51:21.000
# ...

# %%
initial_severity8_Q_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==8) &(file_one_df_cleaned['BOROUGH'] =="QUEENS" )]

initial_severity8_Q_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 2973     2020-07-31 07:43:29                            8
# 2992     2020-07-31 07:30:02                            8
# 6667     2020-07-30 07:17:34                            8
# 10410    2020-07-29 07:33:49                            8
# 11680    2020-07-28 20:29:34                            8
# ...                      ...                          ...
# 20747667 2005-01-03 00:24:47                            8
# 20749617 2005-01-02 12:06:16                            8
# 20749639 2005-01-02 11:57:02                            8
# 20753154 2005-01-01 10:14:48                            8
# 20755198 2005-01-01 00:35:54                            8
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 2973                              8   2020-07-31T07:43:29.000
# 2992                              8   2020-07-31T07:30:13.000
# 6667                              8   2020-07-30T07:17:34.000
# ...

# %%
initial_severity4_Q_avg = initial_severity4_Q_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/926806 
initial_severity5_Q_avg = initial_severity5_Q_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/707092
initial_severity6_Q_avg = initial_severity6_Q_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/620309
initial_severity7_Q_avg = initial_severity7_Q_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/348175
initial_severity8_Q_avg = initial_severity8_Q_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/21275

# %%
average_initial_Q = {'SEVERITY_LEVEL':['4',"5",'6','7',"8"],'AVERAGE_RESPONSE_SECONDS':[initial_severity4_Q_avg.round(),
                                                                                                                             initial_severity5_Q_avg.round(),
                                                                                                                             initial_severity6_Q_avg.round(),
                                                                                                                             initial_severity7_Q_avg.round(),
                                                                                                                             initial_severity8_Q_avg.round()
                                                                                                                             ]}

# %%
initial_severity_Q_df = pd.DataFrame(average_initial_Q)

initial_severity_Q_df
# Out:
#   SEVERITY_LEVEL  AVERAGE_RESPONSE_SECONDS
# 0              4                     482.0
# 1              5                     499.0
# 2              6                     515.0
# 3              7                     657.0
# 4              8                    1886.0

# %%
#Bronx
initial_severity4_Bx_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==4) &(file_one_df_cleaned['BOROUGH'] =="BRONX" )]

initial_severity4_Bx_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 12       2020-07-31 23:54:21                            4
# 26       2020-07-31 23:46:47                            4
# 52       2020-07-31 23:37:15                            4
# 65       2020-07-31 23:31:42                            4
# 69       2020-07-31 23:29:48                            4
# ...                      ...                          ...
# 20755281 2005-01-01 00:14:19                            4
# 20755282 2005-01-01 00:13:40                            4
# 20755297 2005-01-01 00:09:54                            4
# 20755306 2005-01-01 00:07:51                            4
# 20755329 2005-01-01 00:00:43                            4
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 12                                4   2020-07-31T23:56:26.000
# 26                                4   2020-07-31T23:46:58.000
# 52                                4   2020-07-31T23:37:55.000
# ...

# %%
initial_severity5_Bx_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==5) &(file_one_df_cleaned['BOROUGH'] =="BRONX" )]

initial_severity5_Bx_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 9        2020-07-31 23:56:24                            5
# 32       2020-07-31 23:45:20                            5
# 46       2020-07-31 23:39:42                            5
# 68       2020-07-31 23:30:31                            5
# 73       2020-07-31 23:28:29                            5
# ...                      ...                          ...
# 20755271 2005-01-01 00:16:55                            5
# 20755272 2005-01-01 00:16:41                            5
# 20755288 2005-01-01 00:12:07                            5
# 20755311 2005-01-01 00:06:29                            5
# 20755314 2005-01-01 00:04:57                            5
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 9                                 5   2020-07-31T23:56:54.000
# 32                                6   2020-07-31T23:46:35.000
# 46                                5   2020-07-31T23:39:42.000
# ...

# %%
initial_severity6_Bx_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==6) &(file_one_df_cleaned['BOROUGH'] =="BRONX" )]

initial_severity6_Bx_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 54       2020-07-31 23:36:26                            6
# 55       2020-07-31 23:36:16                            6
# 97       2020-07-31 23:20:56                            6
# 148      2020-07-31 23:03:32                            6
# 171      2020-07-31 22:55:32                            6
# ...                      ...                          ...
# 20755239 2005-01-01 00:24:27                            6
# 20755291 2005-01-01 00:11:32                            6
# 20755298 2005-01-01 00:09:42                            6
# 20755322 2005-01-01 00:01:29                            6
# 20755331 2005-01-01 00:00:25                            6
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 54                                6   2020-07-31T23:48:36.000
# 55                                6   2020-07-31T23:36:41.000
# 97                                4   2020-07-31T23:21:51.000
# ...

# %%
initial_severity7_Bx_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==7) &(file_one_df_cleaned['BOROUGH'] =="BRONX" )]

initial_severity7_Bx_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 5        2020-07-31 23:58:02                            7
# 10       2020-07-31 23:54:53                            7
# 31       2020-07-31 23:45:38                            7
# 101      2020-07-31 23:17:38                            7
# 124      2020-07-31 23:10:13                            7
# ...                      ...                          ...
# 20755018 2005-01-01 01:12:28                            7
# 20755102 2005-01-01 00:56:02                            7
# 20755199 2005-01-01 00:35:29                            7
# 20755229 2005-01-01 00:27:31                            7
# 20755287 2005-01-01 00:12:48                            7
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 5                                 7   2020-07-31T23:58:40.000
# 10                                7   2020-07-31T23:57:02.000
# 31                                7   2020-07-31T23:45:46.000
# ...

# %%
initial_severity8_Bx_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==8) &(file_one_df_cleaned['BOROUGH'] =="BRONX" )]

initial_severity8_Bx_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 1964     2020-07-31 13:49:41                            8
# 3430     2020-07-31 02:23:14                            8
# 5355     2020-07-30 15:01:45                            8
# 6089     2020-07-30 11:23:33                            8
# 6811     2020-07-30 05:18:44                            8
# ...                      ...                          ...
# 20747984 2005-01-02 22:13:31                            8
# 20748956 2005-01-02 16:15:41                            8
# 20751134 2005-01-01 22:22:04                            8
# 20753216 2005-01-01 09:49:40                            8
# 20753281 2005-01-01 09:29:40                            8
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 1964                              2   2020-07-31T13:50:34.000
# 3430                              8   2020-07-31T02:23:34.000
# 5355                              2   2020-07-30T15:01:45.000
# ...

# %%
initial_severity4_Bx_avg = initial_severity4_Bx_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/894716
initial_severity5_Bx_avg = initial_severity5_Bx_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/939413
initial_severity6_Bx_avg = initial_severity6_Bx_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/857668
initial_severity7_Bx_avg = initial_severity7_Bx_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/456149
initial_severity8_Bx_avg = initial_severity8_Bx_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/12375

# %%
average_initial_Bx = {'SEVERITY_LEVEL':['4',"5",'6','7',"8"],'AVERAGE_RESPONSE_SECONDS':[initial_severity4_Bx_avg.round(),
                                                                                                                             initial_severity5_Bx_avg.round(),
                                                                                                                             initial_severity6_Bx_avg.round(),
                                                                                                                             initial_severity7_Bx_avg.round(),
                                                                                                                             initial_severity8_Bx_avg.round()
                                                                                                                             ]}

# %%
initial_severity_Bx_df = pd.DataFrame(average_initial_Bx)

initial_severity_Bx_df
# Out:
#   SEVERITY_LEVEL  AVERAGE_RESPONSE_SECONDS
# 0              4                     555.0
# 1              5                     602.0
# 2              6                     688.0
# 3              7                     832.0
# 4              8                     923.0

# %%
#Brooklyn
initial_severity4_Br_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==4) &(file_one_df_cleaned['BOROUGH'] =="BROOKLYN" )]

initial_severity4_Br_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 38       2020-07-31 23:44:00                            4
# 60       2020-07-31 23:33:38                            4
# 99       2020-07-31 23:18:40                            4
# 111      2020-07-31 23:14:31                            4
# 120      2020-07-31 23:11:31                            4
# ...                      ...                          ...
# 20755151 2005-01-01 00:46:03                            4
# 20755156 2005-01-01 00:44:19                            4
# 20755180 2005-01-01 00:39:06                            4
# 20755184 2005-01-01 00:38:52                            4
# 20755319 2005-01-01 00:02:27                            4
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 38                                2   2020-07-31T23:44:16.000
# 60                                4   2020-07-31T23:34:06.000
# 99                                4   2020-07-31T23:18:53.000
# ...

# %%
initial_severity5_Br_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==5) &(file_one_df_cleaned['BOROUGH'] =="BROOKLYN" )]

initial_severity5_Br_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 42       2020-07-31 23:42:33                            5
# 48       2020-07-31 23:39:20                            5
# 59       2020-07-31 23:34:15                            5
# 78       2020-07-31 23:26:25                            5
# 98       2020-07-31 23:19:55                            5
# ...                      ...                          ...
# 20755292 2005-01-01 00:11:29                            5
# 20755301 2005-01-01 00:09:04                            5
# 20755310 2005-01-01 00:06:37                            5
# 20755318 2005-01-01 00:02:28                            5
# 20755332 2005-01-01 00:00:24                            5
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 42                                5   2020-07-31T23:43:00.000
# 48                                5   2020-07-31T23:39:29.000
# 59                                5   2020-07-31T23:34:28.000
# ...

# %%
initial_severity6_Br_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==6) &(file_one_df_cleaned['BOROUGH'] =="BROOKLYN" )]

initial_severity6_Br_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 3        2020-07-31 23:58:54                            6
# 91       2020-07-31 23:22:30                            6
# 106      2020-07-31 23:16:36                            6
# 133      2020-07-31 23:08:21                            6
# 197      2020-07-31 22:44:42                            6
# ...                      ...                          ...
# 20755242 2005-01-01 00:23:10                            6
# 20755274 2005-01-01 00:16:15                            6
# 20755277 2005-01-01 00:15:11                            6
# 20755299 2005-01-01 00:09:29                            6
# 20755309 2005-01-01 00:06:42                            6
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 3                                 6   2020-08-01T00:00:30.000
# 91                                3   2020-07-31T23:22:42.000
# 106                               6   2020-07-31T23:16:47.000
# ...

# %%
initial_severity7_Br_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==7) &(file_one_df_cleaned['BOROUGH'] =="BROOKLYN" )]

initial_severity7_Br_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 20       2020-07-31 23:50:28                            7
# 154      2020-07-31 23:01:56                            7
# 157      2020-07-31 23:01:04                            7
# 160      2020-07-31 23:00:02                            7
# 204      2020-07-31 22:43:17                            7
# ...                      ...                          ...
# 20755135 2005-01-01 00:49:39                            7
# 20755148 2005-01-01 00:46:59                            7
# 20755218 2005-01-01 00:29:19                            7
# 20755247 2005-01-01 00:21:42                            7
# 20755328 2005-01-01 00:00:58                            7
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 20                                7   2020-07-31T23:50:37.000
# 154                               4   2020-07-31T23:02:10.000
# 157                               7   2020-07-31T23:01:16.000
# ...

# %%
initial_severity8_Br_df =  file_one_df_cleaned.loc[(file_one_df_cleaned['INITIAL_SEVERITY_LEVEL_CODE'] ==8) &(file_one_df_cleaned['BOROUGH'] =="BROOKLYN" )]

initial_severity8_Br_df
# Out:
#            INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 919      2020-07-31 19:06:09                            8
# 1411     2020-07-31 16:35:46                            8
# 2812     2020-07-31 09:01:00                            8
# 4253     2020-07-30 20:55:07                            8
# 6018     2020-07-30 11:46:49                            8
# ...                      ...                          ...
# 20747342 2005-01-03 04:05:45                            8
# 20747724 2005-01-02 23:55:53                            8
# 20747761 2005-01-02 23:38:41                            8
# 20750017 2005-01-02 09:17:59                            8
# 20751143 2005-01-01 22:17:48                            8
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 919                               8   2020-07-31T19:07:58.000
# 1411                              8   2020-07-31T16:35:58.000
# 2812                              8   2020-07-31T09:01:44.000
# ...

# %%
initial_severity4_Br_avg = initial_severity4_Br_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/1212580
initial_severity5_Br_avg = initial_severity5_Br_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/1113252
initial_severity6_Br_avg = initial_severity6_Br_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/1050611 
initial_severity7_Br_avg = initial_severity7_Br_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/530829
initial_severity8_Br_avg = initial_severity8_Br_df['INCIDENT_RESPONSE_SECONDS_QY'].sum()/19710

# %%
average_initial_Br = {'SEVERITY_LEVEL':['4',"5",'6','7',"8"],'AVERAGE_RESPONSE_SECONDS':[initial_severity4_Br_avg.round(),
                                                                                                                             initial_severity5_Br_avg.round(),
                                                                                                                             initial_severity6_Br_avg.round(),
                                                                                                                             initial_severity7_Br_avg.round(),
                                                                                                                             initial_severity8_Br_avg.round()
                                                                                                                             ]}

# %%
initial_severity_Br_df = pd.DataFrame(average_initial_Br)

initial_severity_Br_df
# Out:
#   SEVERITY_LEVEL  AVERAGE_RESPONSE_SECONDS
# 0              4                     488.0
# 1              5                     540.0
# 2              6                     563.0
# 3              7                     768.0
# 4              8                    2274.0

# %% [markdown]
# EXPORTING DATA FOR DATABASE

# %%
file_one_df_cleaned4.to_csv('Output/NYC.csv')

file_one_df_B.to_csv('Output/Brooklyn.csv')

file_one_df_BRONKX.to_csv('Output/Bronx.csv')

file_one_df_M.to_csv('Output/Manhattan.csv')

file_one_df_Q.to_csv('Output/Queens.csv')

file_one_df_SI.to_csv('Output/Staten_Island.csv')

average_per_borough_df.to_csv('Output/avg_response_per_borough.csv')

average_before_after_covid_df.to_csv('Output/avg_before_after_covid.csv')

average_before_covid_df.to_csv('Output/avg_before_covid_borough.csv')

average_after_covid_df.to_csv('Output/avg_after_covid_borough.csv')

initial_severity_SI_df.to_csv('Output/initial_severity_SI.csv')

initial_severity_Q_df.to_csv('Output/initial_severity_Q.csv')

initial_severity_M_df.to_csv('Output/initial_severity_M.csv')

initial_severity_Br_df.to_csv('Output/initial_severity_Br.csv')

initial_severity_Bx_df.to_csv('Output/initial_severity_Bx.csv')

initial_severity_vs_response_df.to_csv('Output/initial_severity_NYC.csv')
